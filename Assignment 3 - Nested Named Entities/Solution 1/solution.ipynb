# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\mosta\miniconda3\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (2.7.0)
# Requirement already satisfied: jinja2 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\mosta\miniconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\mosta\miniconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\mosta\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in c:\users\mosta\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\mosta\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mosta\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mosta\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mosta\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mosta\appdata\roaming\python\python312\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\mosta\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\mosta\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\mosta\miniconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\mosta\miniconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\mosta\miniconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mosta\miniconda3\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\mosta\miniconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.0)

# %%
# !python -m spacy download ru_core_news_lg -q

# %% [markdown]
# ## Data Loading and Preparation

# %%
import spacy
import json

def load_data(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            data.append(json.loads(line))
    return data

data = load_data('../train.jsonl')

# %%
def prepare_ner_data(train_data):
    """ Prepare the training data for NER model by sorting entities, adjusting boundaries, and removing overlaps. """
    prepared_data = []
    for data in train_data:
        sentences = data['sentences']
        # Sort entities by length, prioritize longer entities first
        entities = sorted(data['ners'], key=lambda x: x[1] - x[0], reverse=True)
        
        # Adjust end boundary by adding one
        adjusted_entities = [(start, end + 1, label) for start, end, label in entities]
        
        # Remove overlapping entities
        span = set()
        non_overlapping_entities = []
        for start, end, label in adjusted_entities:
            if not any(i in span for i in range(start, end)):
                non_overlapping_entities.append((start, end, label))
                span.update(range(start, end))
        
        prepared_data.append((sentences, {'entities': non_overlapping_entities}))
    
    return prepared_data

training_data = prepare_ner_data(data)

# %%
print(training_data[0][0])
print(training_data[0][1])
# Out:
# Бостон взорвали Тамерлан и Джохар Царнаевы из Северного Кавказа
#
# 19 апреля 2013 года в пригороде Бостона  проходит спецоперация по поимке 19-летнего Джохара Царнаева, подозреваемого в теракте на Бостонском марафоне 15 апреля и в смертельном ранении полицейского на кампусе Массачусетского технологического института 18 апреля.
#
# Второй подозреваемый, его брат, 26-летний Тамерлан Царнаев, был ранен в перестрелке в Уотертауне  и позже скончался в больнице.
#
# Уотертаун и его окрестности фактически переведены на осадное положение: окрестности оцеплены, дороги перекрыты, магазины и бизнесы закрыты, жителей просят не выходить из домов и не приближаться к окнам, над районом спецоперации перекрыты полёты авиации.
#
# В Бостоне приостановлена работа общественного транспорта, включая метро, автобусы, такси и пригородные поезда. Отменены занятия в Гарварде, Массачусетском технологическом институте, Университете Саффолка, Бостонском университете и во всех городских школах.
#
# На сайте ФБР опубликованы фото и видео разыскиваемого.
#
# 19-летний студент Университета штата Массачусетс Джохар Царнаев обучался в средней школе Махачкалы, затем в школе Кембриджа (район Бостона), входил в список стипендиатов Кембриджа.
#
# Секретарь директора школы № 1 Махачкалы Ирина Бандурина подтвердила «Эху Москвы», что Джохар Царнаев учился в данном учебном заведении, но покинул его, не закончив первый класс.
#
# Один из братьев приехал в США вместе с родителями в 2002 году, а другой — самостоятельно в 2004 году.
#
# Инцидент произошел спустя несколько дней после теракта на Бостонском марафоне, во время которого прогремели два взрыва.
# Их жертвами стали три человека, более 180 получили ранения.
#
# {'entities': [(273, 315, 'ORGANIZATION'), (852, 892, 'ORGANIZATION'), (1208, 1247, 'PROFESSION'), (229, 261, 'CRIME'), (1044, 1074, 'ORGANIZATION'), (16, 42, 'FAMILY'), (917, 940, 'ORGANIZATION'), (115, 137, 'EVENT'), (1183, 1205, 'AWARD'), (894, 915, 'ORGANIZATION'), (195, 214, 'EVENT'), (1548, 1567, 'EVENT'), (46, 63, 'LOCATION'), (87, 104, 'LOCATION'), (149, 165, 'PERSON'), (370, 386, 'PERSON'), (1248, 1263, 'PERSON'), (1075, 1089, 'PERSON'), (1294, 1308, 'PERSON'), (65, 79, 'DATE'), (1613, 1627, 'EVENT'), (400, 411, 'EVENT'), (1437, 1448, 'DATE'), (1476, 1487, 'DATE'), (138, 148, 'AGE'), (414, 424, 'CITY'), (1277, 1287, 'ORGANIZATION'), (215, 224, 'DATE'), (316, 325, 'DATE'), (360, 369, 'AGE'), (457, 466, 'CITY'), (1026, 1035, 'AGE'), (1115, 1124, 'CITY'), (1642, 1651, 'NUMBER'), (434, 443, 'EVENT'), (1140, 1149, 'DISTRICT'), (842, 850, 'ORGANIZATION'), (7, 15, 'EVENT'), (714, 721, 'CITY'), (1157, 1164, 'CITY'), (1537, 1544, 'EVENT'), (184, 191, 'CRIME'), (1661, 1668, 'EVENT'), (0, 6, 'CITY'), (328, 334, 'ORDINAL'), (1372, 1378, 'ORDINAL'), (1602, 1608, 'EVENT'), (392, 397, 'EVENT'), (979, 982, 'ORGANIZATION'), (1413, 1416, 'COUNTRY'), (1598, 1601, 'NUMBER'), (1628, 1631, 'NUMBER')]}

# %% [markdown]
# ## Model Setup & Training

# %%
from spacy.training import Example
import random

nlp = spacy.load("ru_core_news_lg")

optimizer = nlp.initialize()

# Training loop
for itn in range(50):
    random.shuffle(training_data)
    losses = {}
    for sentences, annotations in training_data:
        doc = nlp.make_doc(sentences)
        example = Example.from_dict(doc, annotations)
        nlp.update([example], sgd=optimizer, drop=0.5, losses=losses)
    print(f"Iteration {itn}, Losses: {losses}")
# Out:
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Суд Вены освободил Дмитрия Фирташа
#
# Дмитрий Фирташ..." with entities "[(901, 972, 'CRIME'), (1128, 1156, 'ORGANIZATION')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Португалии объявлен трёхдневный траур в память о..." with entities "[(1104, 1139, 'AWARD'), (466, 494, 'EVENT'), (873,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Новым генсеком ООН станет португалец Гутерреш
#
# Ант..." with entities "[(1029, 1085, 'PROFESSION'), (1223, 1263, 'PROFESS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Майк Комри и Оуэн Нолан объявили о завершении хокк..." with entities "[(1082, 1106, 'PROFESSION'), (631, 652, 'DATE'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Число жертв крушения «Булгарии» возросло
# Число пог..." with entities "[(943, 1018, 'ORGANIZATION'), (1165, 1228, 'PROFES...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Москве в штаб Любови Соболь и Ивана Жданова приш..." with entities "[(1464, 1518, 'CRIME'), (179, 220, 'PROFESSION'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Умерла Людмила Зыкина.
#
# Людмила Зыкина среди дру..." with entities "[(1198, 1263, 'ORGANIZATION'), (912, 971, 'ORGANIZ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Вручены Нобелевские премии мира и по литературе в ..." with entities "[(1230, 1278, 'PROFESSION'), (1067, 1111, 'ORGANIZ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Свердловчане первыми в России поднимают уровень ми..." with entities "[(293, 346, 'LAW'), (218, 256, 'ORGANIZATION'), (5...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# Палестинские СМИ прокомментировали отставку мини..." with entities "[(1201, 1226, 'PROFESSION'), (46, 70, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Центробанк отозвал лицензию у московского банка «Г..." with entities "[(235, 335, 'LAW'), (612, 678, 'LAW'), (92, 131, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Временно исполняющим обязанности президента Туниса..." with entities "[(0, 50, 'PROFESSION'), (73, 101, 'ORGANIZATION'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Молодая российская звезда не торопится в НХЛ
#
# Моло..." with entities "[(1078, 1114, 'EVENT'), (54, 89, 'PROFESSION'), (3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Первое голосование по отмене Obamacare закончилось..." with entities "[(141, 187, 'LAW'), (99, 138, 'LAW'), (856, 890, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Скончался бывший премьер-министр России Виктор Чер..." with entities "[(1478, 1587, 'PROFESSION'), (1088, 1181, 'PROFESS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Главным управляющим General Motors назначен Э.Уита..." with entities "[(0, 34, 'PROFESSION'), (303, 335, 'PROFESSION'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Человек, 35 лет назад стрелявший в президента Рейг..." with entities "[(55, 89, 'EVENT'), (250, 283, 'EVENT'), (216, 248...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Главой Bundesbank станет советник канцлера ФРС по ..." with entities "[(460, 521, 'ORGANIZATION'), (577, 629, 'ORGANIZAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Мексика обыграла Германию на ЧМ-2018
# Германия — Ме..." with entities "[(1120, 1143, 'PROFESSION'), (702, 720, 'DATE'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Король Бельгии Альберт II отречётся от престола в ..." with entities "[(844, 891, 'PERSON'), (635, 677, 'DATE'), (365, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Иваново по просьбе РПЦ снесли памятник героям Ве..." with entities "[(390, 452, 'FACILITY'), (1030, 1086, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Российские границы защитит экс-глава ФСБ Чечни и з..." with entities "[(733, 802, 'PROFESSION'), (542, 609, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Марина Голуб погибла в автомобильной аварии_NOTOC_..." with entities "[(1246, 1293, 'PENALTY'), (1183, 1222, 'CRIME'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Андрей Тихонов побил рекорд, установленный 60 лет ..." with entities "[(740, 781, 'DATE'), (1017, 1045, 'EVENT'), (926, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Лионель Месси женился
#
# Лионель Месси
# Звезда испанс..." with entities "[(1395, 1422, 'CRIME'), (1366, 1391, 'PENALTY'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "М.Драги утвержден новым главой Европейского ЦБ
#
# Ли..." with entities "[(359, 411, 'PROFESSION'), (134, 172, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Чернокожий сторонник «Лиги Севера» избран в Сенат ..." with entities "[(729, 759, 'PROFESSION'), (1782, 1805, 'EVENT'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Глава Samsung арестован по делу о коррупции
#
# Ли Дж..." with entities "[(1217, 1263, 'PROFESSION'), (54, 97, 'ORGANIZATIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Путин исключил Грызлова из Совета Безопасности
# Бор..." with entities "[(797, 867, 'ORGANIZATION'), (621, 682, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Российский боксёр Максим Дадашев скончался от полу..." with entities "[(1898, 1932, 'ORGANIZATION'), (1973, 2002, 'ORGAN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Италии умер создатель «киндер-сюрприза» Уильям С..." with entities "[(233, 264, 'DATE'), (321, 343, 'PROFESSION'), (17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Российские регионы ждут еще нескольких отставок гу..." with entities "[(1505, 1550, 'PROFESSION'), (1887, 1923, 'PROFESS...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Капитан катера, сбивший насмерть сенатора от Магад..." with entities "[(1737, 1833, 'PROFESSION'), (134, 212, 'ORGANIZAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Серена Уильямс в пятый раз победила на US Open
# Сер..." with entities "[(126, 172, 'AWARD'), (830, 866, 'EVENT'), (264, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Первое поражение Серены Уильямс в финале Australia..." with entities "[(94, 131, 'EVENT'), (245, 280, 'TIME'), (294, 317...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Жюри Каннского кинофестиваля в 2017 возглавит Педр..." with entities "[(1921, 1962, 'PROFESSION'), (172, 210, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Киеве пройдёт выставка «Антропоморфия украинской..." with entities "[(26, 56, 'EVENT'), (137, 167, 'EVENT'), (90, 115,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ксения Собчак родила первенца
#
# Ксения Собчак
#
# В пя..." with entities "[(46, 76, 'DATE'), (441, 462, 'DATE'), (119, 139, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ю.Чайке дали трех новых заместителей
#
# Совет Федера..." with entities "[(346, 461, 'PROFESSION'), (747, 797, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Д.Медведев назначил А.Бастрыкина главой СК РФ
#
# Пре..." with entities "[(551, 628, 'ORGANIZATION'), (250, 305, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Япония одержала победу над Колумбией на ЧМ-2018
# Ко..." with entities "[(892, 918, 'PROFESSION'), (808, 830, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Петиции против закона Яровой бьют рекорды популярн..." with entities "[(136, 357, 'LAW'), (800, 994, 'LAW'), (374, 555, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Моторолу убили в Донецке
#
# Моторола
# В воскресенье, ..." with entities "[(827, 930, 'PROFESSION'), (35, 70, 'DATE'), (1112...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Новый премьер Японии сформировал свой кабинет
# Синд..." with entities "[(628, 674, 'PROFESSION'), (988, 1034, 'PROFESSION...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Британский актер Дональд Синден умер в 90 лет
# мини..." with entities "[(441, 475, 'ORGANIZATION'), (561, 578, 'WORK_OF_A...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Италии из-за коронавируса из тюрем выпускают бос..." with entities "[(974, 1018, 'PROFESSION'), (863, 895, 'DISEASE'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Казнь женщины из Техаса отложена на 60 дней
# Камера..." with entities "[(837, 870, 'PROFESSION'), (267, 296, 'EVENT'), (2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Японии новый Премьер-министр
#
# слева|Синдзо Абэ —..." with entities "[(406, 469, 'PROFESSION'), (1290, 1353, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Умер Эдуард Назаров — создатель мультфильма «Жил-б..." with entities "[(1426, 1484, 'EVENT'), (454, 502, 'ORGANIZATION')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Б.Обама выдвинул на пост главы ФБР республиканца
#
# ..." with entities "[(510, 545, 'ORGANIZATION'), (1134, 1168, 'CRIME')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Один из пяти лучших программистов в мире уходит из..." with entities "[(960, 1020, 'PROFESSION'), (62, 105, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Владимир Путин выразил соболезнования родным погиб..." with entities "[(440, 474, 'ORGANIZATION'), (100, 130, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Нобелевскую премию по литературе-2016 присудили пе..." with entities "[(0, 37, 'AWARD'), (281, 313, 'AWARD'), (1078, 110...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "По версии «Форбс» российский премьер на порядки вл..." with entities "[(787, 817, 'PROFESSION'), (691, 717, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Умер Леонард Коэн
#
# Леонард Коэн
# 10 ноября 2016 год..." with entities "[(1232, 1274, 'AWARD'), (1730, 1755, 'AWARD'), (16...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Легендарный Freixenet не будет переносить свою шта..." with entities "[(406, 437, 'PROFESSION'), (85, 114, 'ORGANIZATION...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В калифорнийской синагоге при стрельбе погиб один ..." with entities "[(905, 962, 'ORGANIZATION'), (778, 802, 'EVENT'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Пулеметы, автоматы и снайперские винтовки изъяты в..." with entities "[(2098, 2139, 'PROFESSION'), (2417, 2455, 'ORGANIZ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ярослав Песков: очередной заплыв не за горами
# left..." with entities "[(79, 103, 'PROFESSION'), (287, 309, 'ORGANIZATION...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "«Арсенал» надеется получить за Мхитаряна более $27..." with entities "[(830, 851, 'DATE'), (210, 230, 'ORGANIZATION'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Президент Обама прибыл в Ирландию
# left|Барак Обама..." with entities "[(809, 854, 'DATE'), (881, 911, 'ORGANIZATION'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "СМИ: Нападавшего на ФСБ звали Евгений Манюров
# Штаб..." with entities "[(971, 1027, 'EVENT'), (532, 582, 'ORGANIZATION'),...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Бельгийский математик Пьер Делинь стал лауреатом А..." with entities "[(964, 1013, 'FACILITY'), (96, 133, 'ORGANIZATION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В Петербурге рухнула крыша гипермаркета
# Пресс-служ..." with entities "[(758, 856, 'LAW'), (40, 78, 'ORGANIZATION'), (212...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "У.Баффет нашел для своего холдинга второго менедже..." with entities "[(260, 317, 'PROFESSION'), (541, 576, 'PROFESSION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Букву «М» сломали у вестибюля станции московского ..." with entities "[(611, 695, 'CRIME'), (577, 607, 'LAW'), (761, 788...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Б.Обама назначил нового советника по национальной ..." with entities "[(1612, 1656, 'PROFESSION'), (142, 181, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "«Спортинг» возглавил Веркотерен
# Стадион Жозе Алвал..." with entities "[(613, 651, 'EVENT'), (517, 535, 'EVENT'), (140, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "В штате Колорадо полностью отменили рабство
#
# Колор..." with entities "[(261, 299, 'LAW'), (101, 139, 'EVENT'), (622, 648...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Сын магната Р.Мердока вновь стал главой совета дир..." with entities "[(33, 77, 'PROFESSION'), (239, 273, 'ORGANIZATION'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Первый канал отменил победу дочери Алсу и Абрамова..." with entities "[(804, 846, 'PROFESSION'), (57, 86, 'CRIME'), (576...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "СМИ: Кремль обманул А.Кудрина, обещая ему пост пре..." with entities "[(959, 1001, 'PROFESSION'), (828, 863, 'PROFESSION...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Сын А.Лукашенко взял нити силовых структур в свои ..." with entities "[(458, 506, 'PROFESSION'), (944, 976, 'ORGANIZATIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Выставка «С любовью о родном крае» к юбилею Алекса..." with entities "[(1833, 1980, 'ORGANIZATION'), (542, 688, 'ORGANIZ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Глава Комиссии по ценным бумагам США М.Шапиро поки..." with entities "[(714, 777, 'ORGANIZATION'), (157, 196, 'ORGANIZAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Одолев в четвертьфинале канадцев, сборная Россия б..." with entities "[(158, 188, 'EVENT'), (74, 98, 'ORGANIZATION'), (1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Серена Уильямс родила дочь
# Серена Уильямс на корте..." with entities "[(837, 864, 'EVENT'), (388, 412, 'PROFESSION'), (2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "У принца Уильяма и Кейт Миддлтон родился сын
# Принц..." with entities "[(1269, 1317, 'PROFESSION'), (300, 330, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Гароццо принёс Италии золото в фехтовании на рапир..." with entities "[(435, 470, 'PROFESSION'), (1036, 1068, 'AWARD'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Витамин Б для Сочи от художника Кирилла Бородина
# К..." with entities "[(448, 510, 'ORGANIZATION'), (354, 405, 'ORGANIZAT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "У Бооса родился сын
#
# Георгий Боос
# У бывшего главы ..." with entities "[(547, 583, 'PROFESSION'), (208, 238, 'DATE'), (44...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Победителем US Open впервые с 1936 года стал брита..." with entities "[(85, 120, 'EVENT'), (696, 715, 'EVENT'), (329, 34...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "«Локомотив» в 3-й раз стал чемпионом России
# Юрий С..." with entities "[(144, 173, 'EVENT'), (91, 115, 'EVENT'), (911, 93...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Госстрой возглавит В.Токарев
#
# Преемником уволенног..." with entities "[(121, 164, 'PROFESSION'), (1117, 1140, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Самым ценным игроком НБА признан Деррик Роуз
#
# Баск..." with entities "[(104, 162, 'AWARD'), (1197, 1225, 'PROFESSION'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Всероссийский турнир «Олимпийские надежды»
#
# Одну с..." with entities "[(327, 445, 'ORGANIZATION'), (171, 244, 'EVENT'), ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Святейший Патриарх Кирилл прибыл в Санкт-Петербург..." with entities "[(1175, 1228, 'FACILITY'), (1677, 1728, 'FACILITY'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Захват немецкой заложницы в Ираке
# В пятницу, 25 но..." with entities "[(2110, 2161, 'PROFESSION'), (278, 324, 'PROFESSIO...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Д.Медведев снял с должности замсекретаря Совбеза Р..." with entities "[(1055, 1118, 'PROFESSION'), (1739, 1794, 'AWARD')...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Глава «Металлоинвеста» Андрей Варичев умер от пнев..." with entities "[(1647, 1704, 'ORGANIZATION'), (1738, 1781, 'ORGAN...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Умер экс-президент Израиля Шимон Перес
#
# Шимон Пере..." with entities "[(1036, 1070, 'PROFESSION'), (495, 521, 'TIME'), (...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "У стрелка из Лас-Вегаса найден арсенал оружия
# Стре..." with entities "[(173, 221, 'EVENT'), (409, 433, 'EVENT'), (679, 7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Iteration 0, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 43708.101333828265}
# Iteration 1, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 31702.493964091624}
# Iteration 2, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 27906.942871613835}
# Iteration 3, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 25234.671167658827}
# Iteration 4, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 23747.006201757726}
# Iteration 5, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 22357.67307013378}
# Iteration 6, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 21377.868525916852}
# Iteration 7, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 20186.613170554152}
# Iteration 8, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 19790.36949715096}
# Iteration 9, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 19075.71725390869}
# Iteration 10, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 18443.400227986098}
# Iteration 11, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 18245.387170099224}
# Iteration 12, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 17669.815242559704}
# Iteration 13, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 17211.079011977825}
# Iteration 14, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 16989.862202245433}
# Iteration 15, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 16295.65115640796}
# Iteration 16, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 16211.44745767818}
# Iteration 17, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 16013.552988203824}
# Iteration 18, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 15344.005783295192}
# Iteration 19, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14971.635121046651}
# Iteration 20, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14989.458519384109}
# Iteration 21, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14787.735323948695}
# Iteration 22, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14394.258703044638}
# Iteration 23, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14191.546054958862}
# Iteration 24, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 14082.081661716966}
# Iteration 25, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 13680.54861878878}
# Iteration 26, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 13551.940574326116}
# Iteration 27, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 13204.767285175081}
# Iteration 28, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 13139.329577729393}
# Iteration 29, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12974.131093582408}
# Iteration 30, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12843.223856342356}
# Iteration 31, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12556.526793771776}
# Iteration 32, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12403.969771807993}
# Iteration 33, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12278.247905595796}
# Iteration 34, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 12115.286693489725}
# Iteration 35, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11971.473466271615}
# Iteration 36, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11917.066530541353}
# Iteration 37, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11671.789387386654}
# Iteration 38, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11734.14396711193}
# Iteration 39, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11520.440405941767}
# Iteration 40, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11326.883141016066}
# Iteration 41, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11307.357522860251}
# Iteration 42, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 11124.1065585005}
# Iteration 43, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10975.075626054475}
# Iteration 44, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10796.224057959447}
# Iteration 45, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10766.781532060864}
# Iteration 46, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10776.71572971377}
# Iteration 47, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10658.88424215263}
# Iteration 48, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10516.157022927844}
# Iteration 49, Losses: {'tok2vec': 0.0, 'morphologizer': 0.0, 'parser': 0.0, 'ner': 10545.636997881576}

# %%
# Save the model
nlp.to_disk('ner_model')

# %% [markdown]
# ## Test Data Prediction

# %%
test_data = load_data('../test.jsonl')

# %%
def predict_and_save_entities(test_data, output_file_path):
    results = []
    for item in test_data:
        doc = nlp(item['senences'])
        ners = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
        results.append({'ners': ners, 'id': item['id']})
    
    with open(output_file_path, 'w', encoding='utf-8') as file:
        for result in results:
            file.write(json.dumps(result) + '\n')

predict_and_save_entities(test_data, 'test.jsonl')
# Out:
# c:\Users\mosta\miniconda3\Lib\site-packages\spacy\pipeline\attributeruler.py:149: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = self.matcher(doc, allow_missing=True, as_spans=False)
